# %%
# 00000000000000000000000000000000000000  Important Note 00000000000000000000000000000000000000
# use Older Version from spark (V.3.5.1) With Scala 2.12
# https://spark-packages.org/package/graphframes/graphframes
# Configure bashrc file <------- Very Important (source ~/.bashrc)
# export SPARK_OPTS="--packages graphframes:graphframes:0.8.4-spark3.5-s_2.12"
# Run Shell Command 
#- pyspark --packages graphframes:graphframes:0.8.4-spark3.5-s_2.12

# %%
sc.addPyFile('/opt/spark-3.5.1/jars/graphframes-0.8.4-spark3.5-s_2.12.jar')

# %%
from graphframes import GraphFrame

# %%
from pyspark.sql import SparkSession 
spark =  SparkSession.builder.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4049">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# v = spark.createDataFrame([(1, "A"), (2, "B")], ["id", "name"])
# e = spark.createDataFrame([(1, 2, "friend")], ["src", "dst", "relationship"])
# g = GraphFrame(v, e)

# g.vertices.show()
# g.edges.show()
